# %%
import numpy as np
lst4=[5,6,7,8,75]
array = np.array(lst4)
array
# Out:
# array([ 5,  6,  7,  8, 75])

# %% [markdown]
# part 01: Lab task is to implement the following data structure
# 1.List
# 2.array

# %%
import numpy as np
list2=[3,2,1]
array2=np.array(list2)
array2
# Out:
# array([3, 2, 1])

# %%
people = ['Ann', 'Brandon','Chen','David','Emily']
age=[21,12,32,28,23]
weight=[49,56,61,68,70]
height=[160,165,176,185,178]

# %%
import matplotlib.pyplot as plt
plt.scatter(weight,height)
plt.title("Relationship between weight and Height of patients")
plt.ylabel("height in Meters")
plt.xlabel("weight of patients in kgs")
plt.show()

# %%
plt.scatter(weight, height)
plt.title("Relationship between weight and Height of patients")
plt.ylabel("height in Meters")
plt.xlabel("weight of patients in kgs")
plt.show()

# %%
plt.figure(figsize=(12,14))
plt.title("People's weight in kgs", fontsize=16,fontstyle='itlaic')
plt.bar(x=people,height=weight, width=0.6, color='orange',edgecolor='k',alpha=0.6)
plt.xlabel("people",fontsize=15)
plt.ylabel("weight",fontsize=15)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-29f3a071964d> in <cell line: 2>()
#       1 plt.figure(figsize=(12,14))
# ----> 2 plt.title("People's weight in kgs", fontsize=16,fontstyle='itlaic')
#       3 plt.bar(x=people,height=weight, width=0.6, color='orange',edgecolor='k',alpha=0.6)
#       4 plt.xlabel("people",fontsize=15)
#       5 plt.ylabel("weight",fontsize=15)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in title(label, fontdict, loc, pad, y, **kwargs)
#    3082 @_copy_docstring_and_deprecators(Axes.set_title)
#    3083 def title(label, fontdict=None, loc=None, pad=None, *, y=None, **kwargs):
# -> 3084     return gca().set_title(
#    3085         label, fontdict=fontdict, loc=loc, pad=pad, y=y, **kwargs)
#    3086
#
# ...

# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_table("pavan.txt")

# %%
df1
# Out:
#      Name  Height  Weight
# 0  Ashton     155     135
# 1    kate     167     150
# 2   bruce     170     120
# 3     Tom     175     110
# 4    Bill     180     130

# %%
data2 = pd.read_csv("pavan.txt")

# %%
data2
# Out:
#   Name\tHeight\tWeight
# 0     Ashton\t155\t135
# 1       kate\t167\t150
# 2      bruce\t170\t120
# 3        Tom\t175\t110
# 4       Bill\t180\t130

# %%
data3 = pd.read_excel("/excel1.xlsx")

# %%
import numpy as np
